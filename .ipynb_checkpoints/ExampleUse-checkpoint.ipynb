# %%
from fitfov import *

# %%
dec = main("Conv_zscan1__434",r"C:\Users\Bogdan\Downloads\AllenFitting\Data",r"C:\Users\Bogdan\Downloads\AllenFitting\HelperFiles",verbose=True)
# Out:
# H1_MER_set1 (array([-0., -0., -0.]), array([0., 0., 0.], dtype=float32), array([0., 0., 0.], dtype=float32), np.int64(2404), np.int64(1110))
# H2_MER_set1 (array([ 0.40647715, -4.65091237,  0.89155669]), array([-0.37924743,  4.6806884 , -0.8985139 ], dtype=float32), array([-0.48111987,  4.5692897 , -0.8724854 ], dtype=float32), np.int64(2108), np.int64(769))
# H3_MER_set1 (array([ 0.37402795, -4.06475294,  3.14404677]), array([-0.3543275,  4.086584 , -3.148161 ], dtype=float32), array([-0.43293032,  3.99948   , -3.1317458 ], dtype=float32), np.int64(2072), np.int64(693))
# H4_MER_set1 (array([-0.07332041, -3.48913455,  6.67717877]), array([ 0.08130671,  3.4883165 , -6.682477  ], dtype=float32), array([ 0.04934982,  3.4915898 , -6.6612763 ], dtype=float32), np.int64(2050), np.int64(683))
# ...

# %%
### show some genes
plot_multigenes(dec,genes=['Slc17a7','Slc1a3','Gad2','Gfap'])
# Out:
# Viewer(mouse_move_callbacks=[], mouse_wheel_callbacks=[<function dims_scroll at 0x000001B7020AF240>], mouse_drag_callbacks=[<function drag_to_zoom at 0x000001B7020AF380>], mouse_double_click_callbacks=[<function double_click_to_zoom at 0x000001B7020AF2E0>], camera=Camera(center=(0.0, 1394.7805564800897, 1405.753347237905), zoom=0.20130608509097167, angles=(0.0, 0.0, 0.0), perspective=0.0, mouse_pan=True, mouse_zoom=True, orientation=(<DepthAxisOrientation.TOWARDS: 'towards'>, <VerticalAxisOrientation.DOWN: 'down'>, <HorizontalAxisOrientation.RIGHT: 'right'>)), cursor=Cursor(position=(1.0, 1.0), viewbox=None, scaled=True, size=1.0, style=<CursorStyle.STANDARD: 'standard'>), dims=Dims(ndim=2, ndisplay=2, order=(0, 1), axis_labels=('-2', '-1'), rollable=(True, True), range=(RangeTuple(start=-4.183442771434784, stop=2795.8611653645835, step=1.0), RangeTuple(start=6.6414815584818525, stop=2808.674072265625, step=1.0)), margin_left=(0.0, 0.0), margin_right=(0.0, 0.0), point=(1393.818681319
# ...
